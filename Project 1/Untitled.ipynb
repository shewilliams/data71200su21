# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
social_indicators = pd.read_csv("/Users/sheryl/GitHub/data71200su21/Project 1/Social_Indicator_Report_Data.csv")

# %%
social_indicators
# Out:
#        indicator_id                          indicator_name  domain_id  \
# 0                 1                        Average Earnings          5
# 1                 1                        Average Earnings          5
# 2                 1                        Average Earnings          5
# 3                 1                        Average Earnings          5
# 4                 1                        Average Earnings          5
# ...             ...                                     ...        ...
# 16792             9  Admissions to Department of Correction          7
# 16793             9  Admissions to Department of Correction          7
# 16794             9  Admissions to Department of Correction          7
# 16795             9  Admissions to Department of Correction          7
# 16796             9  Admissions to Department of Correction          7
#
#                              domain  agency_city_id  \
# 0      Economic Security & Mobility             210
# ...

# %%
social_indicators.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16797 entries, 0 to 16796
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   indicator_id           16797 non-null  int64
#  1   indicator_name         16797 non-null  object
#  2   domain_id              16797 non-null  int64
#  3   domain                 16797 non-null  object
#  4   agency_city_id         16797 non-null  int64
#  5   agency_name            16797 non-null  object
#  6   dimension_category_id  16797 non-null  int64
#  7   dimension_category     16797 non-null  object
#  8   dimension_id           16797 non-null  int64
#  9   dimension              16797 non-null  object
#  10  industry               4530 non-null   object
#  11  interval               16797 non-null  object
#  12  period                 16797 non-null  int64
#  13  unit                   16797 non-null  object
# ...

# %%
social_indicators.describe()
# Out:
#        indicator_id     domain_id  agency_city_id  dimension_category_id  \
# count  16797.000000  16797.000000    16797.000000           16797.000000
# mean      25.946538      5.012979    14297.414181              16.973448
# std       17.240113      2.044794    34481.853482               8.553873
# min        1.000000      1.000000        1.000000               1.000000
# 25%       11.000000      3.000000       72.000000               8.000000
# 50%       23.000000      5.000000      781.000000              17.000000
# 75%       43.000000      6.000000      841.000000              27.000000
# max      127.000000      8.000000    99999.000000              30.000000
#
#        dimension_id        period
# count  16797.000000  16797.000000
# mean     244.378877   2015.551051
# std      117.498709      4.609749
# min        1.000000   2000.000000
# 25%      202.000000   2013.000000
# 50%      235.000000   2018.000000
# 75%      313.000000   2019.000000
# ...

# %%
social_indicators["indicator_id"].describe()
# Out:
# count    16797.000000
# mean        25.946538
# std         17.240113
# min          1.000000
# 25%         11.000000
# 50%         23.000000
# 75%         43.000000
# max        127.000000
# Name: indicator_id, dtype: float64

# %%
social_indicators.hist
# Out:
# <bound method hist_frame of        indicator_id                          indicator_name  domain_id  \
# 0                 1                        Average Earnings          5
# 1                 1                        Average Earnings          5
# 2                 1                        Average Earnings          5
# 3                 1                        Average Earnings          5
# 4                 1                        Average Earnings          5
# ...             ...                                     ...        ...
# 16792             9  Admissions to Department of Correction          7
# 16793             9  Admissions to Department of Correction          7
# 16794             9  Admissions to Department of Correction          7
# 16795             9  Admissions to Department of Correction          7
# 16796             9  Admissions to Department of Correction          7
#
#                              domain  agency_city_id  \
# ...

# %%
social_indicators.loc[social_indicators['domain'] == "Empowered Residents & Neighborhoods", 'value'].sum()
# Out:
# '75.059875.774.572.743556.458.148872.167.989.491.2944.7649.870.167.471268.367.23979.679.41671.653167.677.480981.78076.40577.835378.260.791260.870.470.673477.4877.770.530271.373.477872.370.81887141.694757.30651.442550.231556.619965.206149.406563.965260.984662.533870.839859.768854.990561.674561.528663.73371.782855.73267.091365.865668.873858.399562.511974.683372.054766.242859.206469.597148.596158.710962.465251.330961.756848.020941.521546.331365.962266.323467.628957.441763.992755.89961.20765.6966.290863.29555.335253.668367.111859.987468.593356.470462.781651.53857.303458.544663.283675.301264.265169.102969.358664.315857.895456.004699.999681.56880.703490.367165.447651.41758.895969.410445.658239.665246.342141.740174.169461.199961.640566.233647.861568.255762.440160.265251.85556.281163.276171.090757.182761.259663.213260.656443.421456.433263.65853.078365.967958.41663.667654.867'

# %%
# %matplotlib inline 
social_indicators.hist(bins=50, figsize=(20,15)) 
plt.show()

# %%
from pandas.plotting import scatter_matrix

attributes = ["domain_id", "period", "dimension_category_id",
              "dimension_id"]
scatter_matrix(social_indicators[attributes], figsize=(12, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe4d07d9fd0>,
# ...
#       dtype=object)
